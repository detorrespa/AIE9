# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000019A600DB390>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x0000019A600D9E50>
# You’re playing the millennial‑era “tongue‑twister” that’s been circling the internet for over a decade, but if we’re going to give you a fun, “real‑world” answer – here’s what the science and pop culture say:
#
# | Origin | “Answer” | Why it’s popular |
# |--------|----------|-----------------|
# | 1935 *Pickwick* (Thomas N. Lea) | “A woodchuck would chuck as much wood as a woodchuck could chuck if a woodchuck could chuck wood.” | This is the original, tongue‑twisting “answer” that sold the riddle itself. |
# | 1988 AP Research (Adam Van Dyke) | About **700 pounds (≈318 kg)** of wood per day | Using the volume of a burrow, the study extrapolated that a woodchuck could theoretically move that much material, though it was meant as a light‑hearted hypothesis. |
# | 2019 *Scientific American* “study” | Roughly **0–1 kg** of wood | Motivated by a viral meme; the researchers got tongue‑in‑cheek: a real woodchuck would likely chuck *nothing* because it doesn’t actually chuck wood—it burrows dirt. |
#
# ### Bottom line
# - **If you’re looking for a laugh:** The trick answer remains the tongue‑twist: “A woodchuck would chuck as much wood as a woodchuck could chuck if a woodchuck could chuck wood.”
# - **If you want a “real” estimate:** scientists have whimsically suggested roughly 700 lb (317 kg) of material if you imagine a woodchuck behaving like a tiny bulldozer.  In practice, a woodchuck simply grinds and burrows earth, not wood.
#
# So, how much wood can a woodchuck chuck? **It’s probably zero, but if you’re generous, say “a lot of wood!”** 🎉🍃

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 24 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-ee3d7e60672b4944a94df0d51c1e0db1"}
# Request 18 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-f08c3c2441a9491baaf04d5046bc0275"}
# Response 21: The classic rhyme goes:
#
# > *How much wood would a wood‑chuck...
# Response 14: A wood‑chuck, if it were really devoted to wood‑chucking, wo...
# Response 12: A classic tongue‑twister! In folklore the answer is usually ...
# Response 15: A classic joke answer would be: **“A wood‑chuck would chuck ...
# Response 20: A classic tongue‑twister answer goes like this: a woodchuck ...
# Response 23: A woodchuck would chuck as much wood as a woodchuck could ch...
# Response 16: If a wood‑chuck could actually chuck wood, the old tongue‑tw...
# Response 5: A classic tongue‑twister, but fun to answer in a pinch:
#
# > *...
# Response 19: A good‑old tongue‑twister answer is:
#
# > “A woodchuck would c...
# Response 1: The classic answer is: **“A wood‑chuck would chuck as much c...
# Response 9: Ah, the classic tongue‑twister! While there's no definitive ...
# Response 11: The classic tongue‑twister never gives a definitive figure—i...
# Response 6: A woodchuck would chuck as much wood as a woodchuck could ch...
# Response 7: A woodchuck would chuck as “much” wood as a woodchuck could ...
# Response 4: The classic tongue‑twister doesn’t have a “real” answer—wood...
# Response 2: This tongue‑twister has more of a playful spirit than a hard...
# Response 13: That line is a classic tongue‑twister rather than a question...
# Response 3: A wood‑chuck would chuck as much wood as it could, if it cou...
# Response 8: **Answer (Request 8)**
#
# The classic tongue‑twister invites...
# Response 22: **Answer to Request 22:**
#
# > “If a woodchuck could chuck woo...
# Response 17: Ah, the classic tongue‑twister that’s been bobbing up and do...
# Response 10: **Excerpt (often attributed to the traditional nursery rhyme...
